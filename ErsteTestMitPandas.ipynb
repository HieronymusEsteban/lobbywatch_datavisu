# %% [markdown]
# ## This is a exploratory notebook for Lobbywatch

# %%
import json
import urllib2
from src.rest_calls import get_all_parlamentarier
import pandas as pd
# %matplotlib inline

# %%
all_parlamentarier = get_all_parlamentarier(300)
# Out:
# loaded 89 parlamentarier

# %%
df = pd.DataFrame(all_parlamentarier)
list_of_numeric_values = ['anzahl_interessenbindung_hoch', 'anzahl_interessenbindung_mittel', 'lobbyfaktor']
for i in list_of_numeric_values:
    df[i] = pd.to_numeric(df[i])

# %%
df.to_csv('AlleParlamentarier.csv', encoding='utf8')

# %% [markdown]
# ## Nützlich ist der group_by befehl
#
# Dieser gibt aber nicht ein dataframe zurück...

# %%
df.groupby('partei').mean()[[ 'anzahl_interessenbindung_hoch']].plot(kind='bar')
df.groupby('partei').mean()[[ 'anzahl_interessenbindung_mittel']].plot(kind='bar')

# %%
sp_df = df[df['partei'] == 'SP'][[ 'partei','anzahl_interessenbindung_hoch','lobbyfaktor','name']]

# %%
print sp_df
# Out:
#    partei  anzahl_interessenbindung_hoch  lobbyfaktor  \
# 2      SP                              1           21
# 6      SP                              6          125
# 8      SP                              1           30
# 9      SP                              2           49
# 10     SP                              4           89
# 11     SP                              2           36
# 13     SP                              0           15
# 15     SP                              1           26
# 30     SP                              3           59
# 38     SP                              2           26
# 39     SP                              0           32
# 40     SP                              1           52
# 42     SP                              1           56
# 44     SP                              3           42
# 51     SP                              2           51
# 63     SP                              1           20
# 64     SP                              0            7
# 68     SP                              4           74
# 69     SP                              1           36
# 74     SP                              0           35
# 83     SP                              0            5
# 87     SP                              0            8
#
#                         name
# 2            Silvia Schenker
# 6      Jean-François Steiert
# 8     Liliane Maury Pasquier
# 9               Hans Stöckli
# 10        Matthias Aebischer
# 11              Evi Allemann
# 13         Jacqueline Badran
# 15       Prisca Birrer-Heimo
# 30       Edith Graf-Litscher
# 38                 Beat Jans
# 39       Jacques-André Maire
# 40          Nadine Masshardt
# 42            Roger Nordmann
# 44           Corrado Pardini
# 51            Silva Semadeni
# 63             Claude Janiak
# 64          Christian Levrat
# 68          Géraldine Savary
# 69           Roberto Zanetti
# 74            Angelo Barrile
# 83  Laurence Fehlmann Rielle
# 87              Mattea Meyer

# %%
sp_df['anzahl_interessenbindung_hoch'] = pd.to_numeric(sp_df['anzahl_interessenbindung_hoch'])

# %% [markdown]
# ## Sort Befehl

# %% [markdown]
# Damit lässt sich das dataframe nach diversen kriterien sortieren.

# %%
df.sort_values('lobbyfaktor', ascending=False)[[ 'partei','anzahl_interessenbindung_hoch','lobbyfaktor','name', 'beruf']]
# Out:
#    partei  anzahl_interessenbindung_hoch  lobbyfaktor  \
# 6      SP                              6          125
# 10     SP                              4           89
# 43    FDP                              3           81
# 59    FDP                              3           80
# 22    CVP                              2           75
# 24    FDP                              1           74
# 68     SP                              4           74
# 37    SVP                              5           73
# 18    CVP                              1           63
# 49    GPS                              3           60
# 46    SVP                              2           59
# 30     SP                              3           59
# 3     CVP                              1           58
# 62    SVP                              2           57
# 42     SP                              1           56
# 65    CVP                              1           54
# 57    CVP                              1           53
# 40     SP                              1           52
# 51     SP                              2           51
# 20    GLP                              1           51
# 48    SVP                              1           51
# 86    GPS                              0           50
# 61    CVP                              0           49
# 4     FDP                              2           49
# 9      SP                              2           49
# 1     FDP                              0           48
# 19    CVP                              1           48
# 5     SVP                              1           47
# 66    BDP                              1           47
# 60    CVP                              2           44
# ..    ...                            ...          ...
# 72    CVP                              0           21
# 84    GPS                              0           21
# 2      SP                              1           21
# 63     SP                              1           20
# 36    FDP                              0           20
# 26    GPS                              0           19
# 31    SVP                              0           17
# 47    CVP                              1           16
# 71    SVP                              0           16
# 13     SP                              0           15
# 75    FDP                              0           15
# 34    SVP                              0           13
# 28    MCR                              0           13
# 14    GLP                              0           12
# 70    GPS                              0           12
# 53    CSP                              0            9
# 45   Lega                              0            9
# 79    SVP                              0            8
# 32    BDP                              0            8
# 87     SP                              0            8
# 73  BastA                              0            7
# 64     SP                              0            7
# 23    FDP                              0            6
# 80    PdA                              0            6
# 81    SVP                              0            6
# 67   None                              0            6
# 85    CVP                              0            6
# 21    SVP                              0            6
# 83     SP                              0            5
# 77    SVP                              0            2
#
#                                 name  \
# 6              Jean-François Steiert
# 10                Matthias Aebischer
# 43                       Ruedi Noser
# 59                      Joachim Eder
# 22                Dominique de Buman
# 24       Corina Eichenberger-Walther
# 68                  Géraldine Savary
# 37                     Thomas Hurter
# 18        Christine Bulliard-Marbach
# 49                       Regula Rytz
# 46                Jean-François Rime
# 30               Edith Graf-Litscher
# 3             Barbara Schmid-Federer
# 62                    Hannes Germann
# 42                    Roger Nordmann
# 65                  Filippo Lombardi
# 57              Pirmin Josef Bischof
# 40                  Nadine Masshardt
# 51                    Silva Semadeni
# 20                Isabelle Chevalley
# 48                      Albert Rösti
# 86                      Lisa Mazzone
# 61  Jean-René Marcel Lucien Fournier
# 4               Daniela Schneeberger
# 9                       Hans Stöckli
# 1                     Bruno Pezzatti
# 19                    Yannick Buttet
# 5                         Jürg Stahl
# 66                  Werner Luginbühl
# 60               Stefan Georg Engler
# ..                               ...
# 72                     Thomas Ammann
# 84                     Jonas Fricker
# 2                    Silvia Schenker
# 63                     Claude Janiak
# 36                   Hugues Hiltpold
# 26                     Bastien Girod
# 31                  Jean-Pierre Grin
# 47                     Markus Ritter
# 71                    Jean-Luc Addor
# 13                 Jacqueline Badran
# 75                    Philippe Bauer
# 34                       Alfred Heer
# 28                       Roger Golay
# 14                  Kathrin Bertschy
# 70                  Christine Häsler
# 53                       Karl Vogler
# 45                    Lorenzo Quadri
# 79                      Marco Chiesa
# 32                      Hans Grunder
# 87                      Mattea Meyer
# 73                      Sibel Arslan
# 64                  Christian Levrat
# 23                      Fathi Derder
# 80             Denis de la Reussille
# 81                   Marcel Dettling
# 67                     Thomas Minder
# 85          Géraldine Marchand-Balet
# 21                    Raymond Clottu
# 83          Laurence Fehlmann Rielle
# 77                    Michaël Buffat
#
#                                                 beruf
# 6   Del. für interkant. Angelegenheiten der Waadtl...
# 10                         Hausmann, Lehrbeauftragter
# 43                                        Unternehmer
# 59                                   a. Regierungsrat
# 22                                             Jurist
# 24                     Mediatorin SAV, Rechtsanwältin
# 68                                       Journalistin
# 37                                        Linienpilot
# 18  Lehrerin, Leiterin eines Landwirtschaftsbetrie...
# 49            Co-Präsidentin Grüne Partei der Schweiz
# 46                                      Industrieller
# 30                        SEV Gewerkschaftssekretärin
# 3                         Familienfrau, Unternehmerin
# 62                             Betriebsökonom, Lehrer
# 42                        Unabhängiger Politikberater
# 65                   Journalist BR, Medienunternehmer
# 57                             Rechtsanwalt und Notar
# 40                        Historikerin, Nationalrätin
# 51                                       Historikerin
# 20                                         Consultant
# 48                                  Dr. Ing. Agr. ETH
# 86                     Chargée de projets associatifs
# 61                                    lic. ès sc. éc.
# 4   Treuhänderin mit eidg. Fachausweis, Inhaberin ...
# 9                     Fürsprecher, alt Stadtpräsident
# 1                                  Dipl. Ing. Agronom
# 19  Conseiller national et président de la commune...
# 5   Mitglied der Geschäftsleitung, Leiter Service ...
# 66                    Leiter Public Affairs, Mobiliar
# 60                             lic.iur., Rechtsanwalt
# ..                                                ...
# 72                            Gemeindepräsident Rüthi
# 84                                 Vater und Hausmann
# 2                                    Sozialarbeiterin
# 63                                            Advokat
# 36                             Unabhängiger Architekt
# 26  Wissenschaftlicher Mitarbeiter/dipl. ETH Umwel...
# 31                                           Landwirt
# 47                                           Landwirt
# 71                                             Anwalt
# 13                                      Unternehmerin
# 75                                             Anwalt
# 34                                   Kleinunternehmer
# 28                                Ehemaliger Polizist
# 14                                           Ökonomin
# 70        Leiterin Kommunikation Kraftwerke Oberhasli
# 53                             Rechtsanwalt und Notar
# 45                                           Redaktor
# 79                           Direttore centro anziani
# 32               Unternehmer, Pat. Ingenieur-Geometer
# 87                                      Nationalrätin
# 73                                           Juristin
# 64                               Präsident SP Schweiz
# 23                              Kommunikationsberater
# 80                               Gemeinderat Le Locle
# 81                                           Landwirt
# 67                              Kaufmann, Unternehmer
# 85                              Présidente de commune
# 21                                Buchhaltungsexperte
# 83  Politologue / Directrice d'un organisme de pré...
# 77                            Filialleiter einer Bank
#
# [89 rows x 5 columns]
