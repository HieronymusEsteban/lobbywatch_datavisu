# %% [markdown]
# ## This is a test notebook

# %%
import json
import urllib2

# %%
parlametarier_id = "21"

my_data = json.load(urllib2.urlopen("http://lobbywatch.ch/de/data/interface/v1/json/table/parlamentarier/aggregated/id/"+ parlametarier_id))

# %%
my_data
# Out:
# {u'build secs': 0.07,
#  u'count': 1,
#  u'data': {u'adresse_firma': None,
#   u'adresse_ort': u'Th\xfcrnen',
#   u'adresse_plz': u'4441',
#   u'adresse_strasse': u'Postfach 48',
#   u'adresse_zusatz': None,
#   u'aemter': u'Landrat des Kantons Basel-Landschaft: von Juli 1999 bis Dezember 2011, Mitglied der Finanzkommission; Landratspr\xe4sidentin Basel-Landschaft: von Juli 2004 bis Juni 2005',
#   u'anzahl_interessenbindung_hoch': u'2',
#   u'anzahl_interessenbindung_hoch_max': u'11',
#   u'anzahl_interessenbindung_hoch_nach_wahl': u'1',
#   u'anzahl_interessenbindung_mittel': u'1',
#   u'anzahl_interessenbindung_mittel_max': u'15',
#   u'anzahl_interessenbindung_mittel_nach_wahl': u'0',
#   u'anzahl_interessenbindung_tief': u'11',
#   u'anzahl_interessenbindung_tief_max': u'41',
#   u'anzahl_interessenbindung_tief_nach_wahl': u'0',
#   u'anzahl_kinder': None,
#   u'anzeige_name': u'Schneeberger, Daniela',
#   u'arbeitssprache': u'de',
# ...

# %%
my_data['interessenbindungen']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-387431a07340> in <module>()
# ----> 1 my_data['interessenbindungen']
#
# KeyError: 'interessenbindungen'
